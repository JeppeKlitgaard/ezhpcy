# %%
import paramiko
from dtuhpc import check_vscode_cli_installed, install_vscode_cli
from dtuhpc.config import config
from dtuhpc.pixi import install_pixi

# %load_ext autoreload
# %autoreload 2

# %%
config
# Out:
# Config(config_dir=WindowsPath('C:/Users/jeppe/.config/dtuhpc'))

# %%
host = "login.hpc.dtu.dk"
username = "s250250"
password = None

# %%
client = paramiko.client.SSHClient()

client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
client.connect(host, username=username, password=password)
_stdin, _stdout, _stderr = client.exec_command("df")
print(_stdout.read().decode())
# client.close()
# Out:
# Exception (client): Error reading SSH protocol banner
# Traceback (most recent call last):
#   File "c:\Users\jeppe\Code\DTUnnel\.venv\Lib\site-packages\paramiko\transport.py", line 2363, in _check_banner
#     buf = self.packetizer.readline(timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\jeppe\Code\DTUnnel\.venv\Lib\site-packages\paramiko\packet.py", line 395, in readline
#     buf += self._read_timeout(timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\jeppe\Code\DTUnnel\.venv\Lib\site-packages\paramiko\packet.py", line 665, in _read_timeout
#     raise EOFError()
# EOFError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\jeppe\Code\DTUnnel\.venv\Lib\site-packages\paramiko\transport.py", line 2179, in run
#     self._check_banner()
#   File "c:\Users\jeppe\Code\DTUnnel\.venv\Lib\site-packages\paramiko\transport.py", line 2367, in _check_banner
#     raise SSHException(
# paramiko.ssh_exception.SSHException: Error reading SSH protocol banner
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# File c:\Users\jeppe\Code\DTUnnel\.venv\Lib\site-packages\paramiko\transport.py:2363, in Transport._check_banner(self)
#    2362 try:
# -> 2363     buf = self.packetizer.readline(timeout)
#    2364 except ProxyCommandFailure:
#
# File c:\Users\jeppe\Code\DTUnnel\.venv\Lib\site-packages\paramiko\packet.py:395, in Packetizer.readline(self, timeout)
#     394 while linefeed_byte not in buf:
# --> 395     buf += self._read_timeout(timeout)
#     396 n = buf.index(linefeed_byte)
#
# File c:\Users\jeppe\Code\DTUnnel\.venv\Lib\site-packages\paramiko\packet.py:665, in Packetizer._read_timeout(self, timeout)
#     664 if len(x) == 0:
# --> 665     raise EOFError()
#     666 break
#
# EOFError:
#
# During handling of the above exception, another exception occurred:
#
# SSHException                              Traceback (most recent call last)
# Cell In[5], line 4
#       1 client = paramiko.client.SSHClient()
#       2
#       3 client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
# ----> 4 client.connect(host, username=username, password=password)
#       5 _stdin, _stdout,_stderr = client.exec_command("df")
#       6 print(_stdout.read().decode())
#       7 # client.close()
#
# File c:\Users\jeppe\Code\DTUnnel\.venv\Lib\site-packages\paramiko\client.py:449, in SSHClient.connect(self, hostname, port, username, password, pkey, key_filename, timeout, allow_agent, look_for_keys, compress, sock, gss_auth, gss_kex, gss_deleg_creds, gss_host, banner_timeout, auth_timeout, channel_timeout, gss_trust_dns, passphrase, disabled_algorithms, transport_factory, auth_strategy)
#     446     other_types = [x for x in sec_opts.key_types if x != keytype]
#     447     sec_opts.key_types = [keytype] + other_types
# --> 449 t.start_client(timeout=timeout)
#     451 # If GSS-API Key Exchange is performed we are not required to check the
#     452 # host key, because the host is authenticated via GSS-API / SSPI as
#     453 # well as our client.
#     454 if not self._transport.gss_kex_used:
#
# File c:\Users\jeppe\Code\DTUnnel\.venv\Lib\site-packages\paramiko\transport.py:768, in Transport.start_client(self, event, timeout)
#     766     e = self.get_exception()
#     767     if e is not None:
# --> 768         raise e
#     769     raise SSHException("Negotiation failed.")
#     770 if event.is_set() or (
#     771     timeout is not None and time.time() >= max_time
#     772 ):
#
# File c:\Users\jeppe\Code\DTUnnel\.venv\Lib\site-packages\paramiko\transport.py:2179, in Transport.run(self)
#    2174 self.packetizer.write_all(b(self.local_version + "\r\n"))
#    2175 self._log(
#    2176     DEBUG,
#    2177     "Local version/idstring: {}".format(self.local_version),
#    2178 )  # noqa
# -> 2179 self._check_banner()
#    2180 # The above is actually very much part of the handshake, but
#    2181 # sometimes the banner can be read but the machine is not
#    2182 # responding, for example when the remote ssh daemon is loaded
#    (...)   2185 # Make sure we can specify a timeout for the initial handshake.
#    2186 # Reuse the banner timeout for now.
#    2187 self.packetizer.start_handshake(self.handshake_timeout)
#
# File c:\Users\jeppe\Code\DTUnnel\.venv\Lib\site-packages\paramiko\transport.py:2367, in Transport._check_banner(self)
#    2365     raise
#    2366 except Exception as e:
# -> 2367     raise SSHException(
#    2368         "Error reading SSH protocol banner" + str(e)
#    2369     )
#    2370 if buf[:4] == "SSH-":
#    2371     break
#
# SSHException: Error reading SSH protocol banner

# %%
install_vscode_cli(client)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 install_vscode_cli(client)
#
# File c:\Users\jeppe\Code\DTUnnel\dtunnel\__init__.py:2, in install_vscode_cli(client)
#       1 from pathlib import Path
# ----> 2 import paramiko
#       3 from dataclasses import dataclass
#       6 @dataclass
#       7 class Paths:
#
# AssertionError: VSCode CLI is already installed
# Socket exception: An existing connection was forcibly closed by the remote host (10054)
